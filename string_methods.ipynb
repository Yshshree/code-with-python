# %%
x="i LOvE yAshSHreE"
print(x)
# Out:
# i LOvE yAshSHreE

# %%
x="i LOvE yAshSHreE"
print(x.upper())
# Out:
# I LOVE YASHSHREE

# %%
x="i LOvE yAshSHreE"
print(x.lower())
# Out:
# i love yashshree

# %%
x="i LOvE yAshSHreE"
print(x.capitalize())
# Out:
# I love yashshree

# %%
x="i LOvE yAshSHreE"
print(x.proper())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-815389982.py in <cell line: 0>()
#       1 x="i LOvE yAshSHreE"
# ----> 2 print(x.proper())
#
# AttributeError: 'str' object has no attribute 'proper'

# %%
x="i LOvE yAshSHreE"
print(x.proper(abc))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3672721530.py in <cell line: 0>()
#       1 x="i LOvE yAshSHreE"
# ----> 2 print(x.proper(abc))
#
# AttributeError: 'str' object has no attribute 'proper'

# %%
x="i LOvE yAshSHreE"
print(x.lower(yash))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-481667630.py in <cell line: 0>()
#       1 x="i LOvE yAshSHreE"
# ----> 2 print(x.lower(yash))
#
# NameError: name 'yash' is not defined

# %%
print(id(x))
# Out:
# 137660672925872

# %%
o=x
x=(x.upper())
print(x)
print(id(x))
# Out:
# I LOVE YASHSHREE
# 137660671280624

# %%
print(o.title())
# Out:
# I Love Yashshree

# %%
print(o.swapcase())
# Out:
# i love yashshree

# %%
print(o.replace('YASHSHREE','yash'))
# Out:
# I LOVE yash

# %%
Y="Rajendra"
print(Y.count('a'))
# Out:
# 2

# %%
print(Y.index('r'))
# Out:
# 6

# %%
print(Y.find('d'))
# Out:
# 5

# %%
Q='       RAJ       '
print(len(Q))
print(Q)
# Out:
# 17
#        RAJ

# %%
print(Q.lstrip())
# Out:
# RAJ

# %%
print(Q.rstrip())
# Out:
#        RAJ

# %%
print(Q.strip())
# Out:
# RAJ

# %%
print(Q.split())
# Out:
# ['RAJ']

# %%
m='Raj'
print(m.isalpha())
# Out:
# True

# %%
m='Raj'
print(m.isnumeric())
# Out:
# False

# %%
print(m.istitle())
# Out:
# True

# %%
print(m.isupper())
# Out:
# False

# %%
print(m.islower())
# Out:
# False
