# %%
-10
# Out:
# -10

# %%
abc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3909374524.py in <cell line: 0>()
# ----> 1 abc
#
# NameError: name 'abc' is not defined

# %%
type(-10)
# Out:
# int

# %%
print (type(10000));
# Out:
# <class 'int'>

# %%
type(1.299)
# Out:
# float

# %%
print(type(-22.45));
# Out:
# <class 'float'>

# %%
print 1.23
# Out:
#   File "/tmp/ipython-input-1686791801.py", line 1
#     print 1.23
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
type(23.444)
# Out:
# float

# %%
print(type(1222))
# Out:
# <class 'int'>

# %%
abc1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2640185257.py in <cell line: 0>()
# ----> 1 abc1
#
# NameError: name 'abc1' is not defined

# %%
type('abc')
# Out:
# str

# %%
"can't"
# Out:
# "can't"

# %%
''' my name yash \nyour name is shree'''
# Out:
# ' my name yash \nyour name is shree'

# %%
print('''my name is yash \nyour name is shree''')
# Out:
# my name is yash
# your name is shree

# %%
(1,2,-1.23,"yash")
# Out:
# (1, 2, -1.23, 'yash')

# %%
type(1,2,-1.23,"yash")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-598302587.py in <cell line: 0>()
# ----> 1 type(1,2,-1.23,"yash")
#
# TypeError: type() takes 1 or 3 arguments

# %%
print(type((1,2,1.23,"raj")))
# Out:
# <class 'tuple'>

# %%
type((1,"raj"))
# Out:
# tuple

# %%
print(type([1,1.23,"yash"]))
# Out:
# <class 'list'>

# %%
type([1,"raj"])
# Out:
# list

# %%
type((1.23,"yash",[1,2]))
# Out:
# tuple

# %%
type([1,3,(1,"raj")])
# Out:
# list

# %%
{"a":100,"b":200,"c":300}
# Out:
# {'a': 100, 'b': 200, 'c': 300}

# %%
type({"a":100,"b":200,"c":300})
# Out:
# dict

# %%
print(type({"a":100,"b":200,"c":300}))
# Out:
# <class 'dict'>

# %%
{"a":100,"b":200,"a":300}
# Out:
# {'a': 300, 'b': 200}

# %%
{1,2,3,4,1,2,3,2,3,2,3}
# Out:
# {1, 2, 3, 4}

# %%
type({1,2,3,4,1,2,3,2,3,2,3})
# Out:
# set

# %%
print({1,2,3,4,1,2,3,2,3,2,3})
# Out:
# {1, 2, 3, 4}

# %%
chr(78)
# Out:
# 'N'

# %%
chr(87)
# Out:
# 'W'

# %%
chr(123)
# Out:
# '{'

# %%
print(id({1,2,3,4,1,2,3,2,3,2,3}))
# Out:
# 136866342529376
